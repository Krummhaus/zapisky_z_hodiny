# %%
import pandas as pd
titanic = pd.read_excel('http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic3.xls')
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
titanic[titanic.name.str.contains('van')]
# Out:
#       pclass  survived                                     name     sex   age  \
# 105        1         0                 Evans, Miss. Edith Corse  female  36.0
# 222        1         0          Ovies y Rodriguez, Mr. Servando    male  28.5
# 669        3         0               Beavan, Mr. William Thomas    male  19.0
# 702        3         0                      Canavan, Miss. Mary  female  21.0
# 703        3         0                     Canavan, Mr. Patrick    male  21.0
# 730        3         0                            Cor, Mr. Ivan    male  27.0
# 753        3         0                         Davies, Mr. Evan    male  22.0
# 771        3         1            Devaney, Miss. Margaret Delia  female  19.0
# 773        3         0                         Dimic, Mr. Jovan    male  42.0
# 879        3         0                       Ivanoff, Mr. Kanio    male   NaN
# 880        3         1                       Jalsevac, Mr. Ivan    male  29.0
# ...

# %%
len(titanic[titanic.name.str.split('.').str.get(1).str.split(' ').str.len() == 2])
# Out:
# 464

# %%
sum(titanic.name.str.split('.').str.get(1).str.split(' ').str.len() == 2)
# Out:
# 464

# %%
titanic.groupby('boat').name.count().argmax()
# Out:
# '13'

# %%
import numpy as np

# %%
np.nan == np.nan
# Out:
# False

# %%
titanic[~titanic.body.isnull()]
# Out:
#       pclass  survived                                            name  \
# 3          1         0            Allison, Mr. Hudson Joshua Creighton
# 9          1         0                         Artagaveytia, Mr. Ramon
# 10         1         0                          Astor, Col. John Jacob
# 25         1         0                             Birnbaum, Mr. Jakob
# 39         1         0                              Brandeis, Mr. Emil
# 60         1         0                   Cavendish, Mr. Tyrell William
# 81         1         0                    Crosby, Capt. Edward Gifford
# 96         1         0                      Douglas, Mr. Walter Donald
# 101        1         0                    Dulles, Mr. William Crothers
# 128        1         0                               Gee, Mr. Arthur H
# 138        1         0                       Graham, Mr. George Edward
# 150        1         0                           Harrison, Mr. William
# ...
